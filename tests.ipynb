# %%
import os
import pymupdf4llm
import sys

file_path = "/Users/pranjalverma/Documents/agent-research/Resume_Pranjal_Verma_New.pdf"

markdown_text = pymupdf4llm.to_markdown(file_path, write_images=True)

print(markdown_text[:1000])
# Out:
# OCR disabled because Tesseract language data not found.
# ## **Pranjal Verma**
#
# � github.com/pranjalv23 | � linkedin.com/in/pranjal-verma-76264923a/ | � pranjal200186@gmail.com | � +91-9971107793
#
# ## Education
#
# **Indian Institute of Technology Kharagpur, India** Jul 2019 - May 2024 Dual Degree (B.Tech + M.Tech) in Aerospace Engineering GPA: 7.49/10.0 **Central Board of Secondary Education** Apr 2017 - Apr 2019 Class XII Percentage: 87.5% **Central Board of Secondary Education** Apr 2015 - Apr 2016 Class X GPA: 8.8/10.0
#
# ## Experience
#
# - **AI Engineer | Asato AI** April 2025 - March 2026 _**Built MCP-enabled and analytics dashboards for subscription intelligence and entity resolution**_
#
# - _•_ Designed a multimodal **GPT-4.1** vision pipeline to extract structured JSON mappings of Microsoft subscriptions, apps, and entitlements, from raw PDF registries, enriching the current Knowledge Base with app-level inclusion and metadata
#
# ...

# %%
print(markdown_text)
# Out:
# ## **Pranjal Verma**
#
# � github.com/pranjalv23 | � linkedin.com/in/pranjal-verma-76264923a/ | � pranjal200186@gmail.com | � +91-9971107793
#
# ## Education
#
# **Indian Institute of Technology Kharagpur, India** Jul 2019 - May 2024 Dual Degree (B.Tech + M.Tech) in Aerospace Engineering GPA: 7.49/10.0 **Central Board of Secondary Education** Apr 2017 - Apr 2019 Class XII Percentage: 87.5% **Central Board of Secondary Education** Apr 2015 - Apr 2016 Class X GPA: 8.8/10.0
#
# ## Experience
#
# - **AI Engineer | Asato AI** April 2025 - March 2026 _**Built MCP-enabled and analytics dashboards for subscription intelligence and entity resolution**_
#
# - _•_ Designed a multimodal **GPT-4.1** vision pipeline to extract structured JSON mappings of Microsoft subscriptions, apps, and entitlements, from raw PDF registries, enriching the current Knowledge Base with app-level inclusion and metadata
#
# ...

# %%
json_data = pymupdf4llm.to_json(file_path)
# Out:
# OCR disabled because Tesseract language data not found.

# %%
json_data
# Out:
# '{"filename": "/Users/pranjalverma/Documents/agent-research/Resume_Pranjal_Verma_New.pdf", "page_count": 1, "toc": [[1, "Education", 1], [1, "Experience", 1], [1, "Projects", 1], [1, "Competitions", 1], [1, "Position of Responsibility", 1], [1, "Technical Skills", 1], [1, "Academic Coursework", 1], [1, "Extra Curricular Activities", 1]], "pages": [{"page_number": 1, "width": 595.2760009765625, "height": 841.8900146484375, "boxes": [{"x0": 245.7169952392578, "y0": 22.576126098632812, "x1": 349.52587890625, "y1": 37.983909606933594, "boxclass": "section-header", "image": null, "table": null, "textlines": [{"bbox": [245.7169952392578, 22.576126098632812, 349.52587890625, 37.983909606933594], "spans": [{"size": 17.21540069580078, "flags": 20, "bidi": 0, "char_flags": 24, "font": "SFRB1728", "color": 0, "alpha": 255, "ascender": 0.800000011920929, "descender": -0.20000000298023224, "text": "Pranjal", "origin": [245.7169952392578, 34.55804443359375], "bbox": [245.7169952392578, 22.57612609
# ...
